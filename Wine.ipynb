# %%
#obtained the data set of wine from https://archive.ics.uci.edu/ml/machine-learning-databases/wine/
#used it to plot the regression line of alcohol vs color_intesity

# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data', sep=',')
perm=np.random.permutation(data.index)
data=data.reindex(perm)
data.columns="Class Alcohol Malic_acid Ash Alcalinity_of_ash Magnesium Total_phenols Flavanoids Nonflavanoid_phenols Proanthocyanins Color_intensity Hue OD280/OD315_of_diluted_wines Proline".split()
data.head(5)
# Out:
#      Class  Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  \
# 155      3    13.84        4.12  2.38               19.5         89
# 52       1    13.77        1.90  2.68               17.1        115
# 64       2    12.37        1.21  2.56               18.1         98
# 74       2    11.66        1.88  1.92               16.0         97
# 85       2    12.16        1.61  2.31               22.8         90
#
#      Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 155           1.80        0.83                  0.48             1.56
# 52            3.00        2.79                  0.39             1.68
# 64            2.42        2.65                  0.37             2.08
# 74            1.61        1.57                  0.34             1.15
# 85            1.78        1.69                  0.43             1.56
#
#      Color_intensity   Hue  OD280/OD315_of_diluted_wines  Proline
# 155             9.01  0.57                          1.64      480
# ...

# %%
Y=data['Alcohol']
X=data['Color_intensity']
#calculating the mean of all values of X and Y
mean_x=np.mean(X)
mean_y=np.mean(Y)
#total number of values
n=len(X)
num=0
den=0
for i in range(n):
    num+=(X[i]-mean_x)*(Y[i]-mean_y)
    den+=(X[i]-mean_x)**2
m=num/den
c=mean_y-mean_x*m
#print the values of m and c
print("y= {0} x + {1}".format(m,c))
# Out:
# y= 0.19063994476555682 x + 12.030025093835572

# %%
#plotting values and the regression line
max_x=np.max(X)+100
min_x=np.min(X)-100

#calculating the line values of x and y
x=np.linspace(min_x,max_x,1000)
y=m*x+c

#plotting the line
plt.plot(x[450:550],y[450:550],color='#58b970',label='Regression Line')

#plotting the scatter points
plt.plot(X,Y,'bo',label='Scatter Plot')

plt.xlabel('Alcohol')
plt.ylabel('Color_intensity')
plt.title('Alcohol vs Color_intensity')
plt.show()
